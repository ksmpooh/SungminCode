# %%
######### json (EH) vs BED (trgt) comparison
#!python3 -m pip install ipykernel -U --user --force-reinstall
#!pip install pandas
import os,glob
import pandas as pd

# %%
df = open("/Users/ksmpooh/Desktop/KU/@research/STR/Common_trgt_repeat_add_eh.v5_w_gangstr.v13.polymorphic.txt","r")
df = df.readlines()
df[0:5]
# Out:
# ['chrX\t148500631\t148500691\tID=AFF2;MOTIFS=GCC;STRUC=(GCC)n\tAFF2\t(GCC)*\tchrX:148500631-148500691\n',
#  'chrX\t67545316\t67545385\tID=AR;MOTIFS=GCA;STRUC=(GCA)n\tAR\t(GCA)*\tchrX:67545316-67545385\n',
#  'chr12\t6936716\t6936773\tID=ATN1;MOTIFS=CAG;STRUC=(CAG)n\tATN1\t(CAG)*\tchr12:6936716-6936773\n',
#  'chr6\t16327633\t16327723\tID=ATXN1;MOTIFS=TGC;STRUC=(TGC)n\tATXN1\t(TGC)*\tchr6:16327633-16327723\n',
#  'chr22\t45795354\t45795424\tID=ATXN10;MOTIFS=ATTCT;STRUC=(ATTCT)n\tATXN10\t(ATTCT)*\tchr22:45795354-45795424\n']

# %%
df = pd.read_table("/Users/ksmpooh/Desktop/KU/@research/STR/Common_trgt_repeat_add_eh.v5_w_gangstr.v13.polymorphic.txt",header=None)
# Out:
#        0          1          2                                      3       4  \
# 0   chrX  148500631  148500691        ID=AFF2;MOTIFS=GCC;STRUC=(GCC)n    AFF2
# 1   chrX   67545316   67545385          ID=AR;MOTIFS=GCA;STRUC=(GCA)n      AR
# 2  chr12    6936716    6936773        ID=ATN1;MOTIFS=CAG;STRUC=(CAG)n    ATN1
# 3   chr6   16327633   16327723       ID=ATXN1;MOTIFS=TGC;STRUC=(TGC)n   ATXN1
# 4  chr22   45795354   45795424  ID=ATXN10;MOTIFS=ATTCT;STRUC=(ATTCT)n  ATXN10
#
#           5                         6
# 0    (GCC)*  chrX:148500631-148500691
# 1    (GCA)*    chrX:67545316-67545385
# 2    (CAG)*     chr12:6936716-6936773
# 3    (TGC)*    chr6:16327633-16327723
# 4  (ATTCT)*   chr22:45795354-45795424

# %%
df
# Out:
#         0          1          2  \
# 0    chrX  148500631  148500691
# 1    chrX   67545316   67545385
# 2   chr12    6936716    6936773
# 3    chr6   16327633   16327723
# 4   chr22   45795354   45795424
# 5   chr12  111598949  111599018
# 6   chr14   92071009   92071042
# 7    chr3   63912684   63912726
# 8    chr9   27573528   27573546
# 9   chr19   13207858   13207897
# 10  chr11  119206289  119206322
# 11   chr3  129172576  129172732
# 12  chr21   43776443   43776479
# 13  chr12   50505001   50505022
# 14  chr19   45770204   45770264
# 15   chrX  147912050  147912110
# 16   chr9   69037261   69037304
# 17  chr19   14496041   14496074
# 18   chr2  190880872  190880920
# 19   chr4    3074876    3074966
# 20  chr16   87604287   87604329
# 21  chr15   22786677   22786701
# 22  chr20    2652733    2652775
# 23  chr14   23321472   23321490
# 24   chr4   41745972   41746032
# 25   chr5  146878727  146878757
# 26   chr4   39348424   39348479
# 27   chr6  170561906  170562017
# 28  chr18   55586155   55586227
#
#                                                     3        4  \
# 0                     ID=AFF2;MOTIFS=GCC;STRUC=(GCC)n     AFF2
# 1                       ID=AR;MOTIFS=GCA;STRUC=(GCA)n       AR
# 2                     ID=ATN1;MOTIFS=CAG;STRUC=(CAG)n     ATN1
# 3                    ID=ATXN1;MOTIFS=TGC;STRUC=(TGC)n    ATXN1
# 4               ID=ATXN10;MOTIFS=ATTCT;STRUC=(ATTCT)n   ATXN10
# 5                    ID=ATXN2;MOTIFS=GCT;STRUC=(GCT)n    ATXN2
# 6                    ID=ATXN3;MOTIFS=GCT;STRUC=(GCT)n    ATXN3
# 7          ID=ATXN7;MOTIFS=GCA,GCC;STRUC=(GCA)n(GCC)n    ATXN7
# 8            ID=C9ORF72;MOTIFS=GGCCCC;STRUC=(GGCCCC)n  C9ORF72
# 9                  ID=CACNA1A;MOTIFS=CTG;STRUC=(CTG)n  CACNA1A
# 10                     ID=CBL;MOTIFS=CGG;STRUC=(CGG)n      CBL
# 11  ID=CNBP;MOTIFS=CAGG,CAGA,CA;STRUC=(CAGG)n(CAGA...     CNBP
# 12  ID=CSTB;MOTIFS=CGCGGGGCGGGG;STRUC=(CGCGGGGCGGGG)n     CSTB
# 13                   ID=DIP2B;MOTIFS=GGC;STRUC=(GGC)n    DIP2B
# 14                    ID=DMPK;MOTIFS=CAG;STRUC=(CAG)n     DMPK
# 15                    ID=FMR1;MOTIFS=CGG;STRUC=(CGG)n     FMR1
# 16               ID=FXN;MOTIFS=A,GAA;STRUC=(A)n(GAA)n      FXN
# 17                   ID=GIPC1;MOTIFS=CCG;STRUC=(CCG)n    GIPC1
# 18                     ID=GLS;MOTIFS=GCA;STRUC=(GCA)n      GLS
# 19     ID=HTT;MOTIFS=CAG,CCG;STRUC=(CAG)nCAACAG(CCG)n      HTT
# 20                    ID=JPH3;MOTIFS=CTG;STRUC=(CTG)n     JPH3
# 21                   ID=NIPA1;MOTIFS=GCG;STRUC=(GCG)n    NIPA1
# 22  ID=NOP56;MOTIFS=GGCCTG,CGCCTG;STRUC=(GGCCTG)n(...    NOP56
# 23                  ID=PABPN1;MOTIFS=GCG;STRUC=(GCG)n   PABPN1
# 24                  ID=PHOX2B;MOTIFS=GCN;STRUC=(GCN)n   PHOX2B
# 25                 ID=PPP2R2B;MOTIFS=GCT;STRUC=(GCT)n  PPP2R2B
# 26  ID=RFC1;MOTIFS=AAAAG,AAAGG,AAGGG,AAGAG,AGAGG,A...     RFC1
# 27                     ID=TBP;MOTIFS=GCA;STRUC=(GCA)n      TBP
# 28                    ID=TCF4;MOTIFS=CAG;STRUC=(CAG)n     TCF4
#
#                       5                                                  6
# 0                (GCC)*                           chrX:148500631-148500691
# 1                (GCA)*                             chrX:67545316-67545385
# 2                (CAG)*                              chr12:6936716-6936773
# 3                (TGC)*                             chr6:16327633-16327723
# 4              (ATTCT)*                            chr22:45795354-45795424
# 5                (GCT)*                          chr12:111598949-111599018
# 6                (GCT)*                            chr14:92071009-92071042
# 7          (GCA)*(GCC)+      chr3:63912684-63912714_chr3:63912714-63912726
# 8             (GGCCCC)*                             chr9:27573528-27573546
# 9                (CTG)*                            chr19:13207858-13207897
# 10               (CGG)*                          chr11:119206289-119206322
# 11  (CAGG)*(CAGA)*(CA)*  chr3:129172576-129172656_chr3:129172656-129172...
# 12      (CGCGGGGCGGGG)*                            chr21:43776443-43776479
# 13               (GGC)*                            chr12:50505001-50505022
# 14               (CAG)*                            chr19:45770204-45770264
# 15               (CGG)*                           chrX:147912050-147912110
# 16           (A)*(GAA)*      chr9:69037261-69037286_chr9:69037286-69037304
# 17               (CCG)*                            chr19:14496041-14496074
# 18               (GCA)*                           chr2:190880872-190880920
# 19   (CAG)*CAACAG(CCG)*          chr4:3074876-3074933_chr4:3074939-3074966
# 20               (CTG)*                            chr16:87604287-87604329
# 21               (GCG)*                            chr15:22786677-22786701
# 22   (GGCCTG)*(CGCCTG)*        chr20:2652733-2652757_chr20:2652757-2652775
# 23               (GCG)*                            chr14:23321472-23321490
# 24               (GCN)*                             chr4:41745972-41746032
# 25               (GCT)*                           chr5:146878727-146878757
# 26             (AARRG)*                             chr4:39348424-39348479
# 27               (GCA)*                           chr6:170561906-170562017
# 28               (CAG)*                            chr18:55586155-55586227
